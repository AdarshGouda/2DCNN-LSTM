# %% [markdown]
# ## **Halim, I ran train and test. See the results below. Also see the report folder for plots.**
#
# A side note: In config file I have grab_frame = 80 but the prepare_raw_data_Processed.py file is grabbing only 40 frames i think. Its because I had set a boolean variable called "alternate" that grabs alternate frames. Thats why you see 1/40 ... 40/40 in the traain output. I need to troubleshoot it to see if its grabbing 40 frames or 80. Based on the accuracy, I think 80 frames are grabbed but its showing 40 count because of tqdm on for loop and the while loop inside the for loop is not recorded by tqdm.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install split-folders
# !pip install -U PyYAML
# Out:
# ...
#      |████████████████████████████████| 596 kB 4.2 MB/s
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/Project/Final_Project_rev3/main.py"
# Out:
#   0% 0/10 [00:00<?, ?actions/s]
#   0% 0/40 [00:00<?, ?actions/s]
#   2% 1/40 [00:01<00:42,  1.10s/actions]
#   5% 2/40 [00:01<00:36,  1.05actions/s]
#   8% 3/40 [00:02<00:33,  1.11actions/s]
#  10% 4/40 [00:03<00:30,  1.18actions/s]
#  12% 5/40 [00:04<00:26,  1.32actions/s]
#  15% 6/40 [00:05<00:30,  1.11actions/s]
#  18% 7/40 [00:06<00:27,  1.20actions/s]
#  20% 8/40 [00:06<00:24,  1.31actions/s]
#  22% 9/40 [00:07<00:27,  1.13actions/s]
#  25% 10/40 [00:08<00:28,  1.05actions/s]
#  28% 11/40 [00:09<00:24,  1.19actions/s]
#  30% 12/40 [00:10<00:21,  1.32actions/s]
#  32% 13/40 [00:10<00:19,  1.39actions/s]
#  35% 14/40 [00:11<00:17,  1.47actions/s]
#  38% 15/40 [00:12<00:19,  1.30actions/s]
#  40% 16/40 [00:13<00:19,  1.21actions/s]
#  42% 17/40 [00:13<00:18,  1.26actions/s]
#  45% 18/40 [00:14<00:18,  1.19actions/s]
#  48% 19/40 [00:15<00:18,  1.12actions/s]
#  50% 20/40 [00:16<00:18,  1.09actions/s]
#  52% 21/40 [00:18<00:18,  1.00actions/s]
# ...

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/Project/Final_Project_rev3/test.py"
# Out:
#   0% 0/10 [00:00<?, ?actions/s]
#   0% 0/10 [00:00<?, ?actions/s]
#  10% 1/10 [00:02<00:22,  2.45s/actions]
#  20% 2/10 [00:03<00:14,  1.85s/actions]
#  30% 3/10 [00:05<00:12,  1.74s/actions]
#  40% 4/10 [00:06<00:08,  1.46s/actions]
#  50% 5/10 [00:07<00:06,  1.30s/actions]
#  60% 6/10 [00:08<00:04,  1.22s/actions]
#  70% 7/10 [00:10<00:03,  1.29s/actions]
#  80% 8/10 [00:11<00:02,  1.29s/actions]
#  90% 9/10 [00:12<00:01,  1.31s/actions]
# 100% 10/10 [00:13<00:00,  1.38s/actions]
#  10% 1/10 [00:14<02:07, 14.21s/actions]
#   0% 0/10 [00:00<?, ?actions/s]
#  10% 1/10 [00:02<00:18,  2.02s/actions]
#  20% 2/10 [00:03<00:13,  1.72s/actions]
#  30% 3/10 [00:05<00:11,  1.66s/actions]
#  40% 4/10 [00:06<00:09,  1.56s/actions]
#  50% 5/10 [00:08<00:07,  1.55s/actions]
#  60% 6/10 [00:09<00:06,  1.52s/actions]
#  70% 7/10 [00:11<00:05,  1.69s/actions]
#  80% 8/10 [00:13<00:03,  1.83s/actions]
#  90% 9/10 [00:15<00:01,  1.97s/actions]
# 100% 10/10 [00:18<00:00,  1.82s/actions]
# ...
